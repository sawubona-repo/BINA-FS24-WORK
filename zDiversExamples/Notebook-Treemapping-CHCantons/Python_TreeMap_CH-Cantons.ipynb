# %% [markdown]
# ## TREEMAP Example Visualization for Swiss Cantons Data
#
# See [plotly reference](https://plotly.com/python/treemaps/) for a more detailed description
#
# OR the [geeksforgeeks blog](https://www.geeksforgeeks.org/treemap-using-plotly-in-python/) for more examples
#
# ---
# History:
# + 2023-04-25 v1 dbe - initial version for BINA FS23 case study projects

# %% [markdown]
# ---
#
# ### Import Libraries and Setup Environment

# %%
import pandas as pd

# %%
# !pip install plotly-express
import plotly.express as px
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting plotly-express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.9/dist-packages (from plotly-express) (1.22.4)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.9/dist-packages (from plotly-express) (0.5.3)
# Requirement already satisfied: plotly>=4.1.0 in /usr/local/lib/python3.9/dist-packages (from plotly-express) (5.13.1)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.9/dist-packages (from plotly-express) (1.10.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.9/dist-packages (from plotly-express) (0.13.5)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.9/dist-packages (from plotly-express) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.20.0->plotly-express) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.20.0->plotly-express) (2022.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5->plotly-express) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=4.1.0->plotly-express) (8.2.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.9.0->plotly-express) (23.1)
# Installing collected packages: plotly-express
# Successfully installed plotly-express-0.4.1

# %% [markdown]
# ---
# ### Swiss Cantons Treemap Data with **plotly.express**
#
# #### Read Data from CSV File

# %%
data = pd.read_csv('https://raw.githubusercontent.com/sawubona-gmbh/BINA-FS23-WORK/main/zDiversExamples/DATA-Treemap-CH-Kantone.csv', sep =';')

# %%
data.head()
# Out:
#    Unnamed: 0   Kanton          Region  Einwohner  Flaeche  WohnungPreis2020  \
# 0           1  Zuerich  Deutschschweiz     1553.6     1729               328
# 1           2     Bern  Deutschschweiz     1046.3     5959               240
# 2           3   Luzern  Deutschschweiz      416.3     1494               256
# 3           4      Uri  Deutschschweiz       37.0     1077               232
# 4           5   Schwyz  Deutschschweiz      162.6      908               219
#
#   bfs_code  bfs_num
# 0       ZH        1
# 1       BE        2
# 2       LU        3
# 3       UR        4
# 4       SZ        5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        26 non-null     int64
#  1   Kanton            26 non-null     object
#  2   Region            26 non-null     object
#  3   Einwohner         26 non-null     float64
#  4   Flaeche           26 non-null     int64
#  5   WohnungPreis2020  26 non-null     int64
#  6   bfs_code          26 non-null     object
#  7   bfs_num           26 non-null     int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 1.8+ KB

# %% [markdown]
# #### Plot Treemap for CH Cantons Data

# %%
fig = px.treemap(data, path=[px.Constant("Schweiz"), 'Region', 'Kanton'], 
                  values='Flaeche',
                  color='WohnungPreis2020', 
                  hover_data=['Einwohner','bfs_code', 'bfs_num'],
                  color_continuous_scale='sunset')
                 
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1260cec5-1bd6-494a-a32c-f26f736c7cd0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1260cec5-1bd6-494a-a32c-f26f736c7cd0")) {                    Plotly.newPlot(                        "1260cec5-1bd6-494a-a32c-f26f736c7cd0",                        [{"branchvalues":"total","customdata":[[695.3,"AG",19,239.0],[55.7,"AR",15,207.0],[16.3,"AI",16,233.0],[291.3,"BL",13,259.0],[196.6,"BS",12,300.0],[1046.3,"BE",2,240.0],[325.2,"FR",10,238.0],[509.1,"GE",25,416.0],[40.7,"GL",8,207.0],[198.9,"GR",18,461.0],[73.8,"JU",26,176.0],[416.3,"LU",3,256.0],[177.3,"NE",24,212.0],[43.9,"NW",7,271.0],[38.4,"OW",6,242.0],[516.7,"SG",17,220.0],[83.6,"SH",14,268.0],[162.6,"SZ",5,219.0],[278.3,"SO",11,223.0],[353.3,"TI",21,222.0],[282.9,"TG",20,218.0],[37.0,"UR",4,232.0],[815.6,"VD",22,304.0],[349.2,"VS",23,240.0],[1553.6,"ZH",1,328.0],[130.2,"ZG",9,390.0],["(?)","(?)","(?)",245.4387797311272],["(?)","(?)","(?)",393.2134502923977],["(?)","(?)","(?)",254.60089760638297],["(?)","(?)","(?)",283.6046258173892]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Flaeche=%{value}<br>parent=%{parent}<br>id=%{id}<br>Einwohner=%{customdata[0]}<br>bfs_code=%{customdata[1]}<br>bfs_num=%{customdata[2]}<br>WohnungPreis2020=%{color}<extra></extra>","ids":["Schweiz/Deutschschweiz/Aargau","Schweiz/Deutschschweiz/Appenzel ARh","Schweiz/Deutschschweiz/Appenzell IRh","Schweiz/Deutschschweiz/Basel-Landschaft","Schweiz/Deutschschweiz/Basel-Stadt","Schweiz/Deutschschweiz/Bern","Schweiz/Westschweiz/Freiburg","Schweiz/Westschweiz/Genf","Schweiz/Deutschschweiz/Glarus","Schweiz/Suedschweiz/Graubuenden","Schweiz/Westschweiz/Jura","Schweiz/Deutschschweiz/Luzern","Schweiz/Westschweiz/Neuenburg","Schweiz/Deutschschweiz/Nidwalden","Schweiz/Deutschschweiz/Obwalden","Schweiz/Deutschschweiz/Sankt Gallen","Schweiz/Deutschschweiz/Schaffhausen","Schweiz/Deutschschweiz/Schwyz","Schweiz/Deutschschweiz/Solothurn","Schweiz/Suedschweiz/Tessin","Schweiz/Deutschschweiz/Thurgau","Schweiz/Deutschschweiz/Uri","Schweiz/Westschweiz/Waadt","Schweiz/Westschweiz/Wallis","Schweiz/Deutschschweiz/Zuerich","Schweiz/Deutschschweiz/Zug","Schweiz/Deutschschweiz","Schweiz/Suedschweiz","Schweiz/Westschweiz","Schweiz"],"labels":["Aargau","Appenzel ARh","Appenzell IRh","Basel-Landschaft","Basel-Stadt","Bern","Freiburg","Genf","Glarus","Graubuenden","Jura","Luzern","Neuenburg","Nidwalden","Obwalden","Sankt Gallen","Schaffhausen","Schwyz","Solothurn","Tessin","Thurgau","Uri","Waadt","Wallis","Zuerich","Zug","Deutschschweiz","Suedschweiz","Westschweiz","Schweiz"],"marker":{"coloraxis":"coloraxis","colors":[239.0,207.0,233.0,259.0,300.0,240.0,238.0,416.0,207.0,461.0,176.0,256.0,212.0,271.0,242.0,220.0,268.0,219.0,223.0,222.0,218.0,232.0,304.0,240.0,328.0,390.0,245.4387797311272,393.2134502923977,254.60089760638297,283.6046258173892]},"name":"","parents":["Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Westschweiz","Schweiz/Westschweiz","Schweiz/Deutschschweiz","Schweiz/Suedschweiz","Schweiz/Westschweiz","Schweiz/Deutschschweiz","Schweiz/Westschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Suedschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Westschweiz","Schweiz/Westschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz","Schweiz","Schweiz",""],"values":[1404,243,173,518,37,5959,1671,282,685,7105,839,1494,803,276,491,2026,299,908,791,2813,991,1077,3212,5225,1729,239,19340,9918,12032,41290],"type":"treemap"}],                        {"template" ...

# %% [markdown]
# ---
# ### Adding new features (columns) to CH Cantons dataframe

# %%
data['Dichte'] = (data['Einwohner']*1000)/(data['Flaeche'])

# %%
data.head(26)
# Out:
#     Unnamed: 0            Kanton          Region  Einwohner  Flaeche  \
# 0            1           Zuerich  Deutschschweiz     1553.6     1729
# 1            2              Bern  Deutschschweiz     1046.3     5959
# 2            3            Luzern  Deutschschweiz      416.3     1494
# 3            4               Uri  Deutschschweiz       37.0     1077
# 4            5            Schwyz  Deutschschweiz      162.6      908
# 5            6          Obwalden  Deutschschweiz       38.4      491
# 6            7         Nidwalden  Deutschschweiz       43.9      276
# 7            8            Glarus  Deutschschweiz       40.7      685
# 8            9               Zug  Deutschschweiz      130.2      239
# 9           10          Freiburg     Westschweiz      325.2     1671
# 10          11         Solothurn  Deutschschweiz      278.3      791
# 11          12       Basel-Stadt  Deutschschweiz      196.6       37
# 12          13  Basel-Landschaft  Deutschschweiz      291.3      518
# 13          14      Schaffhausen  Deutschschweiz       83.6      299
# 14          15      Appenzel ARh  Deutschschweiz       55.7      243
# 15          16     Appenzell IRh  Deutschschweiz       16.3      173
# 16          17      Sankt Gallen  Deutschschweiz      516.7     2026
# 17          18       Graubuenden     Suedschweiz      198.9     7105
# 18          19            Aargau  Deutschschweiz      695.3     1404
# 19          20           Thurgau  Deutschschweiz      282.9      991
# 20          21            Tessin     Suedschweiz      353.3     2813
# 21          22             Waadt     Westschweiz      815.6     3212
# 22          23            Wallis     Westschweiz      349.2     5225
# 23          24         Neuenburg     Westschweiz      177.3      803
# 24          25              Genf     Westschweiz      509.1      282
# 25          26              Jura     Westschweiz       73.8      839
#
#     WohnungPreis2020 bfs_code  bfs_num       Dichte
# 0                328       ZH        1   898.554078
# 1                240       BE        2   175.583152
# 2                256       LU        3   278.647925
# 3                232       UR        4    34.354689
# 4                219       SZ        5   179.074890
# 5                242       OW        6    78.207739
# 6                271       NW        7   159.057971
# 7                207       GL        8    59.416058
# 8                390       ZG        9   544.769874
# 9                238       FR       10   194.614004
# 10               223       SO       11   351.833123
# 11               300       BS       12  5313.513514
# 12               259       BL       13   562.355212
# 13               268       SH       14   279.598662
# 14               207       AR       15   229.218107
# 15               233       AI       16    94.219653
# 16               220       SG       17   255.034551
# 17               461       GR       18    27.994370
# 18               239       AG       19   495.227920
# 19               218       TG       20   285.469223
# 20               222       TI       21   125.595450
# 21               304       VD       22   253.922790
# 22               240       VS       23    66.832536
# 23               212       NE       24   220.797011
# 24               416       GE       25  1805.319149
# 25               176       JU       26    87.961859

# %%
fig2 = px.treemap(data, path=[px.Constant("Schweiz"), 'Region', 'Kanton'], 
                  values='Dichte',
                  color='WohnungPreis2020', 
                  hover_data=['Einwohner','Flaeche','bfs_code', 'bfs_num'],
                  color_continuous_scale='gnbu')

# see https://plotly.com/python/styling-plotly-express/ for more information about styling a plotly figure 
# or https://plotly.com/python/text-and-annotations/ for text and annotations in python figures                
fig2.update_layout(margin = dict(t=50, l=25, r=25, b=25),
                   title ="CH Kantone - Bevölkerungsdichte vs. Wohnungspreise pro m2/J")
fig2.add_annotation(text="Hohe Einwohnerdichte+Teure Mieten", x=0.9, y=0.7)
fig2.update_traces(textposition='top left')

fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="fe7bd8fe-a82a-4124-bc2a-6500394a2540" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe7bd8fe-a82a-4124-bc2a-6500394a2540")) {                    Plotly.newPlot(                        "fe7bd8fe-a82a-4124-bc2a-6500394a2540",                        [{"branchvalues":"total","customdata":[[695.3,1404,"AG",19,239.0],[55.7,243,"AR",15,207.0],[16.3,173,"AI",16,233.0],[291.3,518,"BL",13,259.0],[196.6,37,"BS",12,300.0],[1046.3,5959,"BE",2,240.0],[325.2,1671,"FR",10,238.0],[509.1,282,"GE",25,416.0],[40.7,685,"GL",8,207.0],[198.9,7105,"GR",18,461.0],[73.8,839,"JU",26,176.0],[416.3,1494,"LU",3,256.0],[177.3,803,"NE",24,212.0],[43.9,276,"NW",7,271.0],[38.4,491,"OW",6,241.99999999999997],[516.7,2026,"SG",17,220.0],[83.6,299,"SH",14,268.0],[162.6,908,"SZ",5,219.0],[278.3,791,"SO",11,223.0],[353.3,2813,"TI",21,222.0],[282.9,991,"TG",20,218.0],[37.0,1077,"UR",4,232.0],[815.6,3212,"VD",22,304.0],[349.2,5225,"VS",23,240.0],[1553.6,1729,"ZH",1,327.99999999999994],[130.2,239,"ZG",9,390.0],["(?)","(?)","(?)","(?)",286.2891328104385],["(?)","(?)","(?)","(?)",265.5618355096465],["(?)","(?)","(?)","(?)",362.3778546488578],["(?)","(?)","(?)","(?)",301.3680306966799]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Dichte=%{value}<br>parent=%{parent}<br>id=%{id}<br>Einwohner=%{customdata[0]}<br>Flaeche=%{customdata[1]}<br>bfs_code=%{customdata[2]}<br>bfs_num=%{customdata[3]}<br>WohnungPreis2020=%{color}<extra></extra>","ids":["Schweiz/Deutschschweiz/Aargau","Schweiz/Deutschschweiz/Appenzel ARh","Schweiz/Deutschschweiz/Appenzell IRh","Schweiz/Deutschschweiz/Basel-Landschaft","Schweiz/Deutschschweiz/Basel-Stadt","Schweiz/Deutschschweiz/Bern","Schweiz/Westschweiz/Freiburg","Schweiz/Westschweiz/Genf","Schweiz/Deutschschweiz/Glarus","Schweiz/Suedschweiz/Graubuenden","Schweiz/Westschweiz/Jura","Schweiz/Deutschschweiz/Luzern","Schweiz/Westschweiz/Neuenburg","Schweiz/Deutschschweiz/Nidwalden","Schweiz/Deutschschweiz/Obwalden","Schweiz/Deutschschweiz/Sankt Gallen","Schweiz/Deutschschweiz/Schaffhausen","Schweiz/Deutschschweiz/Schwyz","Schweiz/Deutschschweiz/Solothurn","Schweiz/Suedschweiz/Tessin","Schweiz/Deutschschweiz/Thurgau","Schweiz/Deutschschweiz/Uri","Schweiz/Westschweiz/Waadt","Schweiz/Westschweiz/Wallis","Schweiz/Deutschschweiz/Zuerich","Schweiz/Deutschschweiz/Zug","Schweiz/Deutschschweiz","Schweiz/Suedschweiz","Schweiz/Westschweiz","Schweiz"],"labels":["Aargau","Appenzel ARh","Appenzell IRh","Basel-Landschaft","Basel-Stadt","Bern","Freiburg","Genf","Glarus","Graubuenden","Jura","Luzern","Neuenburg","Nidwalden","Obwalden","Sankt Gallen","Schaffhausen","Schwyz","Solothurn","Tessin","Thurgau","Uri","Waadt","Wallis","Zuerich","Zug","Deutschschweiz","Suedschweiz","Westschweiz","Schweiz"],"marker":{"coloraxis":"coloraxis","colors":[239.0,207.0,233.0,259.0,300.0,240.0,238.0,416.0,207.0,461.0,176.0,256.0,212.0,271.0,241.99999999999997,220.0,268.0,219.0,223.0,222.0,218.0,232.0,304.0,240.0,327.99999999999994,390.0,286.2891328104385,265.5618355096465,362.3778546488578,301.3680306966799]},"name":"","parents":["Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Westschweiz","Schweiz/Westschweiz","Schweiz/Deutschschweiz","Schweiz/Suedschweiz","Schweiz/Westschweiz","Schweiz/Deutschschweiz","Schweiz/Westschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Suedschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz/Westschweiz","Schweiz/Westschweiz","Schweiz/Deutschschweiz","Schweiz/Deutschschweiz","Schweiz","Schweiz"," ...

# %% [markdown]
# ---
# ### Exporting Treemap Figures as html/png Images

# %%
# !pip install -U kaleido
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.7 MB/s eta 0:00:00
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1

# %%
import kaleido

# %%
fig2.write_html('/content/sample_data/CH-Treemap2.html')

# %%
fig2.write_image('/content/sample_data/CH-Treemap2a.png')

# %%
import plotly.io as pio
pio.write_image(fig2, '/content/sample_data/CH-Treemap2b.png')
